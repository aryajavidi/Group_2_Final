# %%
import pandas as pd

# %%
airbnb_df = pd.read_csv("train.csv")

# %%
pd.options.display.max_columns = None

# %%
airbnb_df.head()
# Out:
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee city  \
# 0  Real Bed              strict          True  NYC
# 1  Real Bed              strict          True  NYC
# ...

# %%
airbnb_df_2 = airbnb_df.drop(columns=["description","name","thumbnail_url"])
airbnb_df_2
# Out:
#              id  log_price property_type        room_type  \
# 0       6901257   5.010635     Apartment  Entire home/apt
# 1       6304928   5.129899     Apartment  Entire home/apt
# 2       7919400   4.976734     Apartment  Entire home/apt
# 3      13418779   6.620073         House  Entire home/apt
# 4       3808709   4.744932     Apartment  Entire home/apt
# ...         ...        ...           ...              ...
# 74106  14549287   4.605170     Apartment     Private room
# 74107  13281809   5.043425     Apartment  Entire home/apt
# 74108  18688039   5.220356     Apartment  Entire home/apt
# 74109  17045948   5.273000     Apartment  Entire home/apt
# 74110   3534845   4.852030          Boat  Entire home/apt
#
#                                                amenities  accommodates  \
# 0      {"Wireless Internet","Air conditioning",Kitche...             3
# 1      {"Wireless Internet","Air conditioning",Kitche...             7
# ...

# %%
airbnb_df_2.to_csv("airbnb_df.csv", index=False)

# %%
airbnb_df_2["neighbourhood"]= airbnb_df_2["neighbourhood"].str.replace("'"," ")
#ny_data['has_pool']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'pool'))
#.str.replace('{', '')

# %%
ny_data = airbnb_df[airbnb_df["city"]=="NYC"]

# %%
ny_data.head()
# Out:
#           id  log_price property_type        room_type  \
# 0    6901257   5.010635     Apartment  Entire home/apt
# 1    6304928   5.129899     Apartment  Entire home/apt
# 2    7919400   4.976734     Apartment  Entire home/apt
# 10   5578513   4.605170     Apartment     Private room
# 18  17589436   4.882802     Apartment  Entire home/apt
#
#                                             amenities  accommodates  \
# 0   {"Wireless Internet","Air conditioning",Kitche...             3
# 1   {"Wireless Internet","Air conditioning",Kitche...             7
# 2   {TV,"Cable TV","Wireless Internet","Air condit...             5
# 10  {Internet,"Wireless Internet","Air conditionin...             2
# 18  {TV,"Cable TV",Internet,"Wireless Internet","A...             2
#
#     bathrooms  bed_type cancellation_policy  cleaning_fee city  \
# 0         1.0  Real Bed              strict          True  NYC
# 1         1.0  Real Bed              strict          True  NYC
# ...

# %%
all_amenities=ny_data['amenities'].str.replace('{', '').str.replace('}', '').str.replace('"', '').str.cat(sep=',')
amenities_list=all_amenities.split(',')
amenities_dict={}
for each_amenity in amenities_list: 
    if each_amenity in amenities_dict: 
        amenities_dict[each_amenity]+=1
    else: 
        amenities_dict[each_amenity]=1
amenities_dict
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# {'Wireless Internet': 31304,
#  'Air conditioning': 27159,
#  'Kitchen': 30068,
#  'Heating': 29523,
#  'Family/kid friendly': 13582,
#  'Essentials': 27561,
#  'Hair dryer': 17451,
#  'Iron': 16552,
#  'translation missing: en.hosting_amenity_50': 11306,
#  'Washer': 12375,
#  'Dryer': 12223,
#  'Smoke detector': 25768,
#  'Fire extinguisher': 10123,
#  'Shampoo': 19071,
#  'Hangers': 20225,
#  'TV': 20765,
#  'Cable TV': 8641,
#  'Breakfast': 3012,
#  'Buzzer/wireless intercom': 11979,
#  'Carbon monoxide detector': 19438,
#  'Laptop friendly workspace': 17637,
#  'Internet': 17541,
#  'Pets allowed': 3533,
#  'Wheelchair accessible': 1956,
# ...

# %%
def sort_dict_by_value(d, reverse = False):
    return dict(sorted(d.items(), key = lambda x: x[1], reverse = reverse))

sort_dict_by_value(amenities_dict, reverse=True)
# Out:
# {'Wireless Internet': 31304,
#  'Kitchen': 30068,
#  'Heating': 29523,
#  'Essentials': 27561,
#  'Air conditioning': 27159,
#  'Smoke detector': 25768,
#  'TV': 20765,
#  'Hangers': 20225,
#  'Carbon monoxide detector': 19438,
#  'Shampoo': 19071,
#  'Laptop friendly workspace': 17637,
#  'Internet': 17541,
#  'Hair dryer': 17451,
#  'Iron': 16552,
#  'Family/kid friendly': 13582,
#  'Washer': 12375,
#  'Dryer': 12223,
#  'Buzzer/wireless intercom': 11979,
#  'translation missing: en.hosting_amenity_50': 11306,
#  'First aid kit': 10124,
#  'Fire extinguisher': 10123,
#  'translation missing: en.hosting_amenity_49': 9255,
#  'Elevator': 9027,
#  'Cable TV': 8641,
#  'Lock on bedroom door': 8138,
#  '24-hour check-in': 5870,
#  'Safety card': 3923,
#  'Self Check-In': 3538,
#  'Pets allowed': 3533,
#  'Pets live on this property': 3265,
#  'Free parking on premises': 3134,
#  'Breakfast': 3012,
#  'Refrigerator': 3010,
#  'Doorman': 2904,
#  'Hot water': 2771,
# ...

# %%
keys_to_keep = ["Wireless Internet","TV","First aid kit","Cable TV","Pets allowed","Coffee maker","BBQ grill","Indoor Fireplace","Dishwasher","Washer","Dryer"]

dict_for_chart = {k: v for k, v in amenities_dict.items() if k in keys_to_keep}

print(dict_for_chart)
# Out:
# {'Wireless Internet': 31304, 'Washer': 12375, 'Dryer': 12223, 'TV': 20765, 'Cable TV': 8641, 'Pets allowed': 3533, 'First aid kit': 10124, 'Coffee maker': 2207, 'Dishwasher': 1268, 'BBQ grill': 329}

# %%
amenities_type=list(amenities_dict.keys())
amenities_type_price={}
for each_amenity in amenities_type: 
    # each_amenity=amenities_type[0]
    amenities_type_price[each_amenity]=ny_data[ny_data['amenities'].str.contains(each_amenity)]['log_price'].mean()
    
amenities_type_price
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:5: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """
# {'Wireless Internet': 4.721595155139393,
#  'Air conditioning': 4.779690663803625,
#  'Kitchen': 4.732433521412895,
#  'Heating': 4.737167110226136,
#  'Family/kid friendly': 4.956388059567028,
#  'Essentials': 4.726582627257077,
#  'Hair dryer': 4.789257142530715,
#  'Iron': 4.778088165230573,
#  'translation missing: en.hosting_amenity_50': 4.558325164866552,
#  'Washer': 4.862159112962818,
#  'Dryer': 4.869536554953579,
#  'Smoke detector': 4.733188569228169,
#  'Fire extinguisher': 4.7639179518680415,
#  'Shampoo': 4.781238870565657,
#  'Hangers': 4.729399160750997,
#  'TV': 4.852576325373715,
#  'Cable TV': 4.984469358072617,
#  'Breakfast': 4.706748932991778,
#  'Buzzer/wireless intercom': 4.8104780326180965,
#  'Carbon monoxide detector': 4.761377447970387,
# ...

# %%
sorted_amen_dict = sort_dict_by_value(amenities_type_price, reverse=True)
sorted_amen_dict
# Out:
# {'Dog(s)': nan,
#  'Indoor fireplace': 5.152128347516917,
#  'Dishwasher': 5.052021345666021,
#  'Wheelchair accessible': 5.003211681397305,
#  'Cable TV': 4.984469358072617,
#  'Bathtub': 4.959888213248954,
#  'Family/kid friendly': 4.956388059567028,
#  'Outlet covers': 4.949082438465,
#  'Private entrance': 4.941526209904224,
#  'Elevator': 4.901585054835116,
#  'Dryer': 4.869536554953579,
#  'Washer': 4.862159112962818,
#  '24-hour check-in': 4.859948317208181,
#  'Coffee maker': 4.857952191061239,
#  'TV': 4.852576325373715,
#  'Oven': 4.824169467224025,
#  'Extra pillows and blankets': 4.82383951625078,
#  'Cooking basics': 4.816195021166236,
#  'Pets allowed': 4.815241918810173,
#  'Dishes and silverware': 4.811119260852243,
#  'Buzzer/wireless intercom': 4.8104780326180965,
#  'Stove': 4.809654438416809,
#  'Single level home': 4.805924309053482,
#  'Safety card': 4.803062640969356,
#  'Wide doorway': 4.802664807096817,
#  'Wide entryway': 4.802006958078905,
# ...

# %%
amenities_type2=list(dict_for_chart.keys())
amenities_type_price2={}
for each_amenity in amenities_type2: 
    # each_amenity=amenities_type[0]
    amenities_type_price2[each_amenity]=ny_data[ny_data['amenities'].str.contains(each_amenity)]['log_price'].mean()
    
amenities_type_price2
# Out:
# {'Wireless Internet': 4.721595155139393,
#  'Washer': 4.862159112962818,
#  'Dryer': 4.869536554953579,
#  'TV': 4.852576325373715,
#  'Cable TV': 4.984469358072617,
#  'Pets allowed': 4.815241918810173,
#  'First aid kit': 4.700456890196349,
#  'Coffee maker': 4.857952191061239,
#  'Dishwasher': 5.052021345666021,
#  'BBQ grill': 4.921373018326372}

# %%
import matplotlib.pyplot as plt

# %%
labels = list(amenities_type_price2.keys())
values = list(amenities_type_price2.values())

# %%
plt.bar(labels, values)
plt.xlabel("Amenity")
plt.ylabel("Average Cost of Rental (Log)")
# Out:
# Text(0, 0.5, 'Average Cost of Rental (Log)')

# %%
def has_amenity(amenity_list, amenity): 
    if amenity in amenity_list: 
        return True
    else: 
        return False

# %%
ny_data['has_pool']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'pool'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_fireplace']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'indoor fireplace'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_wifi']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'wireless_internet'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_kitchen']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'kitchen'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_dishwasher']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'dishwasher'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data_cleaned = ny_data[["log_price", 
                           "room_type",
                           "accommodates",
                           "neighbourhood",
                           "zipcode",
                           "bedrooms",
                           "bathrooms", 
                           'review_scores_rating', 
                           'has_pool', 
                           'has_fireplace',
                           'has_wifi',
                           'has_kitchen',
                           'has_dishwasher'
                          ]]

# %%
ny_data['has_pool'].value_counts()
# Out:
# False    31988
# True       361
# Name: has_pool, dtype: int64

# %%
ny_data_cleaned.head()
# Out:
#     log_price        room_type  accommodates     neighbourhood  zipcode  \
# 0    5.010635  Entire home/apt             3  Brooklyn Heights    11201
# 1    5.129899  Entire home/apt             7    Hell's Kitchen    10019
# 2    4.976734  Entire home/apt             5            Harlem    10027
# 10   4.605170     Private room             2     Alphabet City  10009.0
# 18   4.882802  Entire home/apt             2   Lower East Side    10002
#
#     bedrooms  bathrooms  review_scores_rating  has_pool  has_fireplace  \
# 0        1.0        1.0                 100.0     False          False
# 1        3.0        1.0                  93.0     False          False
# 2        1.0        1.0                  92.0     False          False
# 10       1.0        1.0                  93.0     False          False
# 18       1.0        1.0                  86.0     False          False
#
#     has_wifi  has_kitchen  has_dishwasher
# 0      False         True           False
# ...

# %%
ny_data_cleaned.shape[0]
# Out:
# 32349

# %%
ny_data_cleaned.dropna()
# Out:
#        log_price        room_type  accommodates       neighbourhood  zipcode  \
# 0       5.010635  Entire home/apt             3    Brooklyn Heights    11201
# 1       5.129899  Entire home/apt             7      Hell's Kitchen    10019
# 2       4.976734  Entire home/apt             5              Harlem    10027
# 10      4.605170     Private room             2       Alphabet City  10009.0
# 18      4.882802  Entire home/apt             2     Lower East Side    10002
# ...          ...              ...           ...                 ...      ...
# 74094   3.688879     Private room             2         East Harlem  10035.0
# 74096   3.912023     Private room             2  Washington Heights    10032
# 74097   4.700480     Private room             2             Chelsea  10011.0
# 74100   4.605170     Private room             2        Williamsburg  11211.0
# 74108   5.220356  Entire home/apt             5        Williamsburg  11206.0
#
# ...

# %%
ny_data_cleaned.to_csv("ny_data_w_5_amenities.csv", index=False)

# %%
ny_data_cleaned.shape[0]
# Out:
# 32349

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df2 = ny_data_cleaned.copy()
df2['room_type'] = le.fit_transform(df2['room_type']) 
df2.head()
# Out:
#     log_price  room_type  accommodates     neighbourhood  zipcode  bedrooms  \
# 0    5.010635          0             3  Brooklyn Heights    11201       1.0
# 1    5.129899          0             7    Hell's Kitchen    10019       3.0
# 2    4.976734          0             5            Harlem    10027       1.0
# 10   4.605170          1             2     Alphabet City  10009.0       1.0
# 18   4.882802          0             2   Lower East Side    10002       1.0
#
#     bathrooms  review_scores_rating  has_pool  has_fireplace  has_wifi  \
# 0         1.0                 100.0     False          False     False
# 1         1.0                  93.0     False          False     False
# 2         1.0                  92.0     False          False     False
# 10        1.0                  93.0     False          False     False
# 18        1.0                  86.0     False          False     False
#
#     has_kitchen  has_dishwasher
# 0          True           False
# ...

# %%
df3 = df2.copy()
df3['neighbourhood'] = le.fit_transform(df2['neighbourhood']) 
df3.head()
# Out:
#     log_price  room_type  accommodates  neighbourhood  zipcode  bedrooms  \
# 0    5.010635          0             3             20    11201       1.0
# 1    5.129899          0             7             88    10019       3.0
# 2    4.976734          0             5             87    10027       1.0
# 10   4.605170          1             2              1  10009.0       1.0
# 18   4.882802          0             2            109    10002       1.0
#
#     bathrooms  review_scores_rating  has_pool  has_fireplace  has_wifi  \
# 0         1.0                 100.0     False          False     False
# 1         1.0                  93.0     False          False     False
# 2         1.0                  92.0     False          False     False
# 10        1.0                  93.0     False          False     False
# 18        1.0                  86.0     False          False     False
#
#     has_kitchen  has_dishwasher
# 0          True           False
# 1          True           False
# ...

# %%
df4 = df3.copy()
df4['zipcode'] = le.fit_transform(df2['zipcode']) 
df4.head()
# Out:
#     log_price  room_type  accommodates  neighbourhood  zipcode  bedrooms  \
# 0    5.010635          0             3             20      154       1.0
# 1    5.129899          0             7             88       33       3.0
# 2    4.976734          0             5             87       43       1.0
# 10   4.605170          1             2              1       17       1.0
# 18   4.882802          0             2            109        4       1.0
#
#     bathrooms  review_scores_rating  has_pool  has_fireplace  has_wifi  \
# 0         1.0                 100.0     False          False     False
# 1         1.0                  93.0     False          False     False
# 2         1.0                  92.0     False          False     False
# 10        1.0                  93.0     False          False     False
# 18        1.0                  86.0     False          False     False
#
#     has_kitchen  has_dishwasher
# 0          True           False
# 1          True           False
# ...

# %%
df4.dtypes
# Out:
# log_price               float64
# room_type                 int32
# accommodates              int64
# neighbourhood             int32
# zipcode                   int32
# bedrooms                float64
# bathrooms               float64
# review_scores_rating    float64
# has_pool                   bool
# has_fireplace              bool
# has_wifi                   bool
# has_kitchen                bool
# has_dishwasher             bool
# dtype: object

# %%
df4.isnull().sum()
# Out:
# log_price                  0
# room_type                  0
# accommodates               0
# neighbourhood              0
# zipcode                    0
# bedrooms                  47
# bathrooms                 99
# review_scores_rating    7321
# has_pool                   0
# has_fireplace              0
# has_wifi                   0
# has_kitchen                0
# has_dishwasher             0
# dtype: int64

# %%
df4.dropna(inplace=True)

# %%
df4.isnull().sum()
# Out:
# log_price               0
# room_type               0
# accommodates            0
# neighbourhood           0
# zipcode                 0
# bedrooms                0
# bathrooms               0
# review_scores_rating    0
# has_pool                0
# has_fireplace           0
# has_wifi                0
# has_kitchen             0
# has_dishwasher          0
# dtype: int64

# %%
df4.head()
# Out:
#     log_price  room_type  accommodates  neighbourhood  zipcode  bedrooms  \
# 0    5.010635          0             3             20      154       1.0
# 1    5.129899          0             7             88       33       3.0
# 2    4.976734          0             5             87       43       1.0
# 10   4.605170          1             2              1       17       1.0
# 18   4.882802          0             2            109        4       1.0
#
#     bathrooms  review_scores_rating  has_pool  has_fireplace  has_wifi  \
# 0         1.0                 100.0     False          False     False
# 1         1.0                  93.0     False          False     False
# 2         1.0                  92.0     False          False     False
# 10        1.0                  93.0     False          False     False
# 18        1.0                  86.0     False          False     False
#
#     has_kitchen  has_dishwasher
# 0          True           False
# 1          True           False
# ...

# %% [markdown]
# df4.isnull()

# %%
X = df4.drop("log_price", axis=1)
y= df4["log_price"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
# reg = LinearRegression().fit(X_train, y_train)
reg = RandomForestRegressor().fit(X_train, y_train)

# %%
y_pred = reg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)

# %%
print(mse)
# Out:
# 0.13127528910752548

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)

print("R-squared value:", r2)
# Out:
# R-squared value: 0.6876224072297743

# %%
df4.to_csv('NY_data_simple.csv', index=False)

# %%
df4.head()
# Out:
#     log_price  room_type  accommodates  neighbourhood  zipcode  bedrooms  \
# 0    5.010635          0             3             20      154       1.0
# 1    5.129899          0             7             88       33       3.0
# 2    4.976734          0             5             87       43       1.0
# 10   4.605170          1             2              1       17       1.0
# 18   4.882802          0             2            109        4       1.0
#
#     bathrooms  review_scores_rating  has_pool  has_fireplace  has_wifi  \
# 0         1.0                 100.0     False          False     False
# 1         1.0                  93.0     False          False     False
# 2         1.0                  92.0     False          False     False
# 10        1.0                  93.0     False          False     False
# 18        1.0                  86.0     False          False     False
#
#     has_kitchen  has_dishwasher
# 0          True           False
# 1          True           False
# ...
