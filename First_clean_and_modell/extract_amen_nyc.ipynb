# %%
import pandas as pd

# %%
airbnb_df = pd.read_csv("../Resources/train.csv")

# %%
pd.options.display.max_columns = None

# %%
airbnb_df.head()
# Out:
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee city  \
# 0  Real Bed              strict          True  NYC
# 1  Real Bed              strict          True  NYC
# ...

# %%
airbnb_df["neighbourhood"]= airbnb_df["neighbourhood"].str.replace("'"," ")
#ny_data['has_pool']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'pool'))
#.str.replace('{', '')

# %%
ny_data = airbnb_df[airbnb_df["city"]=="NYC"]

# %%
ny_data.head()
# Out:
#           id  log_price property_type        room_type  \
# 0    6901257   5.010635     Apartment  Entire home/apt
# 1    6304928   5.129899     Apartment  Entire home/apt
# 2    7919400   4.976734     Apartment  Entire home/apt
# 10   5578513   4.605170     Apartment     Private room
# 18  17589436   4.882802     Apartment  Entire home/apt
#
#                                             amenities  accommodates  \
# 0   {"Wireless Internet","Air conditioning",Kitche...             3
# 1   {"Wireless Internet","Air conditioning",Kitche...             7
# 2   {TV,"Cable TV","Wireless Internet","Air condit...             5
# 10  {Internet,"Wireless Internet","Air conditionin...             2
# 18  {TV,"Cable TV",Internet,"Wireless Internet","A...             2
#
#     bathrooms  bed_type cancellation_policy  cleaning_fee city  \
# 0         1.0  Real Bed              strict          True  NYC
# 1         1.0  Real Bed              strict          True  NYC
# ...

# %%
all_amenities=ny_data['amenities'].str.replace('{', '').str.replace('}', '').str.replace('"', '').str.cat(sep=',')
amenities_list=all_amenities.split(',')
amenities_dict={}
for each_amenity in amenities_list: 
    if each_amenity in amenities_dict: 
        amenities_dict[each_amenity]+=1
    else: 
        amenities_dict[each_amenity]=1
amenities_dict
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# {'Wireless Internet': 31304,
#  'Air conditioning': 27159,
#  'Kitchen': 30068,
#  'Heating': 29523,
#  'Family/kid friendly': 13582,
#  'Essentials': 27561,
#  'Hair dryer': 17451,
#  'Iron': 16552,
#  'translation missing: en.hosting_amenity_50': 11306,
#  'Washer': 12375,
#  'Dryer': 12223,
#  'Smoke detector': 25768,
#  'Fire extinguisher': 10123,
#  'Shampoo': 19071,
#  'Hangers': 20225,
#  'TV': 20765,
#  'Cable TV': 8641,
#  'Breakfast': 3012,
#  'Buzzer/wireless intercom': 11979,
#  'Carbon monoxide detector': 19438,
#  'Laptop friendly workspace': 17637,
#  'Internet': 17541,
#  'Pets allowed': 3533,
#  'Wheelchair accessible': 1956,
# ...

# %%
def sort_dict_by_value(d, reverse = False):
    return dict(sorted(d.items(), key = lambda x: x[1], reverse = reverse))

sort_dict_by_value(amenities_dict, reverse=True)
# Out:
# {'Wireless Internet': 31304,
#  'Kitchen': 30068,
#  'Heating': 29523,
#  'Essentials': 27561,
#  'Air conditioning': 27159,
#  'Smoke detector': 25768,
#  'TV': 20765,
#  'Hangers': 20225,
#  'Carbon monoxide detector': 19438,
#  'Shampoo': 19071,
#  'Laptop friendly workspace': 17637,
#  'Internet': 17541,
#  'Hair dryer': 17451,
#  'Iron': 16552,
#  'Family/kid friendly': 13582,
#  'Washer': 12375,
#  'Dryer': 12223,
#  'Buzzer/wireless intercom': 11979,
#  'translation missing: en.hosting_amenity_50': 11306,
#  'First aid kit': 10124,
#  'Fire extinguisher': 10123,
#  'translation missing: en.hosting_amenity_49': 9255,
#  'Elevator': 9027,
#  'Cable TV': 8641,
#  'Lock on bedroom door': 8138,
#  '24-hour check-in': 5870,
#  'Safety card': 3923,
#  'Self Check-In': 3538,
#  'Pets allowed': 3533,
#  'Pets live on this property': 3265,
#  'Free parking on premises': 3134,
#  'Breakfast': 3012,
#  'Refrigerator': 3010,
#  'Doorman': 2904,
#  'Hot water': 2771,
# ...

# %%
amenities_type=list(amenities_dict.keys())
amenities_type_price={}
for each_amenity in amenities_type: 
    # each_amenity=amenities_type[0]
    amenities_type_price[each_amenity]=ny_data[ny_data['amenities'].str.contains(each_amenity)]['log_price'].mean()
    
amenities_type_price
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:5: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """
# {'Wireless Internet': 4.721595155139393,
#  'Air conditioning': 4.779690663803625,
#  'Kitchen': 4.732433521412895,
#  'Heating': 4.737167110226136,
#  'Family/kid friendly': 4.956388059567028,
#  'Essentials': 4.726582627257077,
#  'Hair dryer': 4.789257142530715,
#  'Iron': 4.778088165230573,
#  'translation missing: en.hosting_amenity_50': 4.558325164866552,
#  'Washer': 4.862159112962818,
#  'Dryer': 4.869536554953579,
#  'Smoke detector': 4.733188569228169,
#  'Fire extinguisher': 4.7639179518680415,
#  'Shampoo': 4.781238870565657,
#  'Hangers': 4.729399160750997,
#  'TV': 4.852576325373715,
#  'Cable TV': 4.984469358072617,
#  'Breakfast': 4.706748932991778,
#  'Buzzer/wireless intercom': 4.8104780326180965,
#  'Carbon monoxide detector': 4.761377447970387,
# ...

# %%
sorted_amen_dict = sort_dict_by_value(amenities_type_price, reverse=True)
sorted_amen_dict
# Out:
# {'Dog(s)': nan,
#  'Indoor fireplace': 5.152128347516917,
#  'Dishwasher': 5.052021345666021,
#  'Wheelchair accessible': 5.003211681397305,
#  'Cable TV': 4.984469358072617,
#  'Bathtub': 4.959888213248954,
#  'Family/kid friendly': 4.956388059567028,
#  'Outlet covers': 4.949082438465,
#  'Private entrance': 4.941526209904224,
#  'Elevator': 4.901585054835116,
#  'Dryer': 4.869536554953579,
#  'Washer': 4.862159112962818,
#  '24-hour check-in': 4.859948317208181,
#  'Coffee maker': 4.857952191061239,
#  'TV': 4.852576325373715,
#  'Oven': 4.824169467224025,
#  'Extra pillows and blankets': 4.82383951625078,
#  'Cooking basics': 4.816195021166236,
#  'Pets allowed': 4.815241918810173,
#  'Dishes and silverware': 4.811119260852243,
#  'Buzzer/wireless intercom': 4.8104780326180965,
#  'Stove': 4.809654438416809,
#  'Single level home': 4.805924309053482,
#  'Safety card': 4.803062640969356,
#  'Wide doorway': 4.802664807096817,
#  'Wide entryway': 4.802006958078905,
# ...

# %%
sort_dict_by_value(amenities_dict, reverse=True)
# Out:
# {'Wireless Internet': 31304,
#  'Kitchen': 30068,
#  'Heating': 29523,
#  'Essentials': 27561,
#  'Air conditioning': 27159,
#  'Smoke detector': 25768,
#  'TV': 20765,
#  'Hangers': 20225,
#  'Carbon monoxide detector': 19438,
#  'Shampoo': 19071,
#  'Laptop friendly workspace': 17637,
#  'Internet': 17541,
#  'Hair dryer': 17451,
#  'Iron': 16552,
#  'Family/kid friendly': 13582,
#  'Washer': 12375,
#  'Dryer': 12223,
#  'Buzzer/wireless intercom': 11979,
#  'translation missing: en.hosting_amenity_50': 11306,
#  'First aid kit': 10124,
#  'Fire extinguisher': 10123,
#  'translation missing: en.hosting_amenity_49': 9255,
#  'Elevator': 9027,
#  'Cable TV': 8641,
#  'Lock on bedroom door': 8138,
#  '24-hour check-in': 5870,
#  'Safety card': 3923,
#  'Self Check-In': 3538,
#  'Pets allowed': 3533,
#  'Pets live on this property': 3265,
#  'Free parking on premises': 3134,
#  'Breakfast': 3012,
#  'Refrigerator': 3010,
#  'Doorman': 2904,
#  'Hot water': 2771,
# ...

# %%
def has_amenity(amenity_list, amenity): 
    if amenity in amenity_list: 
        return True
    else: 
        return False

# %%
ny_data['has_pool']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'pool'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_fireplace']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'indoor fireplace'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_wifi']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'wireless internet') or has_amenity(x, 'internet'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_kitchen']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'kitchen'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_dishwasher']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'dishwasher'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_cable']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'cable tv'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_washer']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'washer') or has_amenity(x, 'washer/dryer'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_dryer']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'dryer') or has_amenity(x, 'washer/dryer'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_dishwasher']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'dishwasher'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_smoke_detector']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'smoke detector'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_co_detector']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'carbon monoxide detector'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_first_aid']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'first aid kit'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_fire_extinguisher']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'fire extinguisher'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['pets_allowed']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'pets allowed'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_refrigerator']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'refrigerator'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_clothes_iron']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'iron'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_dishwasher']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'dishwasher'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_free_parking']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'free parking on premises'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_oven']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'oven') or has_amenity(x, 'stove'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_elevator']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'elevator'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_microwave']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'microwave'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_hair_dryer']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'hair dryer'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_gym']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'gym'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_coffee_maker']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'coffee maker'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_bathtub']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'bathtub'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['is_wheelchair_accessible']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'wheelchair accessible'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_hottub']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'hot tub'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['smoking_allowed']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'smoking allowed'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_patio_or_balcony']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'patio or balcony'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_garden_or_backyard']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'garden or backyard'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_bbq_grill']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'bbq grill'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data['has_game_console']=ny_data['amenities'].str.lower().apply(lambda x: has_amenity(x, 'game console'))
# Out:
# C:\Users\zacha\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_data.head()
# Out:
#           id  log_price property_type        room_type  \
# 0    6901257   5.010635     Apartment  Entire home/apt
# 1    6304928   5.129899     Apartment  Entire home/apt
# 2    7919400   4.976734     Apartment  Entire home/apt
# 10   5578513   4.605170     Apartment     Private room
# 18  17589436   4.882802     Apartment  Entire home/apt
#
#                                             amenities  accommodates  \
# 0   {"Wireless Internet","Air conditioning",Kitche...             3
# 1   {"Wireless Internet","Air conditioning",Kitche...             7
# 2   {TV,"Cable TV","Wireless Internet","Air condit...             5
# 10  {Internet,"Wireless Internet","Air conditionin...             2
# 18  {TV,"Cable TV",Internet,"Wireless Internet","A...             2
#
#     bathrooms  bed_type cancellation_policy  cleaning_fee city  \
# 0         1.0  Real Bed              strict          True  NYC
# 1         1.0  Real Bed              strict          True  NYC
# ...

# %%
ny_data["has_cable"].value_counts()
# Out:
# False    23708
# True      8641
# Name: has_cable, dtype: int64

# %%
ny_data.loc[:, "has_pool":].apply(pd.Series.value_counts)
# Out:
#        has_pool  has_fireplace  has_wifi  has_kitchen  has_dishwasher  \
# False     31988          31120       891         2281           31081
# True        361           1229     31458        30068            1268
#
#        has_cable  has_washer  has_dryer  has_smoke_detector  has_co_detector  \
# False      23708       19545       9772                6581            12911
# True        8641       12804      22577               25768            19438
#
#        has_first_aid  has_fire_extinguisher  pets_allowed  has_refrigerator  \
# False          22225                  22226         28816             29339
# True           10124                  10123          3533              3010
#
#        has_clothes_iron  has_free_parking  has_oven  has_elevator  \
# False             15797             29215     29580         23322
# True              16552              3134      2769          9027
#
#        has_microwave  has_hair_dryer  has_gym  has_coffee_maker  has_bathtub  \
# ...

# %%
ny_data.head()
# Out:
#           id  log_price property_type        room_type  \
# 0    6901257   5.010635     Apartment  Entire home/apt
# 1    6304928   5.129899     Apartment  Entire home/apt
# 2    7919400   4.976734     Apartment  Entire home/apt
# 10   5578513   4.605170     Apartment     Private room
# 18  17589436   4.882802     Apartment  Entire home/apt
#
#                                             amenities  accommodates  \
# 0   {"Wireless Internet","Air conditioning",Kitche...             3
# 1   {"Wireless Internet","Air conditioning",Kitche...             7
# 2   {TV,"Cable TV","Wireless Internet","Air condit...             5
# 10  {Internet,"Wireless Internet","Air conditionin...             2
# 18  {TV,"Cable TV",Internet,"Wireless Internet","A...             2
#
#     bathrooms  bed_type cancellation_policy  cleaning_fee city  \
# 0         1.0  Real Bed              strict          True  NYC
# 1         1.0  Real Bed              strict          True  NYC
# ...

# %%
ny_data2 = ny_data.drop(columns=["amenities","description","name","thumbnail_url","first_review","host_has_profile_pic","host_identity_verified","host_response_rate","last_review","cleaning_fee"])
ny_data2.head()
# Out:
#           id  log_price property_type        room_type  accommodates  \
# 0    6901257   5.010635     Apartment  Entire home/apt             3
# 1    6304928   5.129899     Apartment  Entire home/apt             7
# 2    7919400   4.976734     Apartment  Entire home/apt             5
# 10   5578513   4.605170     Apartment     Private room             2
# 18  17589436   4.882802     Apartment  Entire home/apt             2
#
#     bathrooms  bed_type cancellation_policy city  host_since instant_bookable  \
# 0         1.0  Real Bed              strict  NYC  2012-03-26                f
# 1         1.0  Real Bed              strict  NYC  2017-06-19                t
# 2         1.0  Real Bed            moderate  NYC  2016-10-25                t
# 10        1.0  Real Bed              strict  NYC  2013-03-27                f
# 18        1.0  Real Bed              strict  NYC  2015-08-17                f
#
#      latitude  longitude     neighbourhood  number_of_reviews  \
# ...

# %%
ny_data2.to_csv("nyc_w_most_amens.csv", index=False)

# %%
ny_data['has_pool'].value_counts()
# Out:
# False    31988
# True       361
# Name: has_pool, dtype: int64

# %% [markdown]
# df4.isnull()
