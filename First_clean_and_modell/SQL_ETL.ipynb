# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
full_df = pd.read_csv("airbnb_df.csv")
full_df.head()
# Out:
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ... instant_bookable  \
# 0  Real Bed              strict          True  ...                f
# ...

# %%
full_df.dtypes
# Out:
# id                          int64
# log_price                 float64
# property_type              object
# room_type                  object
# amenities                  object
# accommodates                int64
# bathrooms                 float64
# bed_type                   object
# cancellation_policy        object
# cleaning_fee                 bool
# city                       object
# first_review               object
# host_has_profile_pic       object
# host_identity_verified     object
# host_response_rate         object
# host_since                 object
# instant_bookable           object
# last_review                object
# latitude                  float64
# longitude                 float64
# neighbourhood              object
# number_of_reviews           int64
# review_scores_rating      float64
# zipcode                    object
# bedrooms                  float64
# beds                      float64
# dtype: object

# %%
simplified_encoded_df = pd.read_csv("NY_data_simple.csv")
simplified_encoded_df.head()
# Out:
#    log_price  room_type  accommodates  neighbourhood  zipcode  bedrooms  \
# 0   5.010635          0             3             20      154       1.0
# 1   5.129899          0             7             88       33       3.0
# 2   4.976734          0             5             87       43       1.0
# 3   4.605170          1             2              1       17       1.0
# 4   4.882802          0             2            109        4       1.0
#
#    bathrooms  review_scores_rating  has_pool
# 0        1.0                 100.0     False
# 1        1.0                  93.0     False
# 2        1.0                  92.0     False
# 3        1.0                  93.0     False
# 4        1.0                  86.0     False

# %%
simplified_encoded_df.dtypes
# Out:
# log_price               float64
# room_type                 int64
# accommodates              int64
# neighbourhood             int64
# zipcode                   int64
# bedrooms                float64
# bathrooms               float64
# review_scores_rating    float64
# has_pool                   bool
# dtype: object

# %%
engine = create_engine('postgresql://postgres:Nelson+704@localhost:5432/airbnb_database')

# %%
full_df.to_sql('raw_data', engine, index=False)

# %%
simplified_encoded_df.to_sql('simplified_encoded_data', engine, index=False)
